# %%
import warnings
import pandas as pd 
import numpy as np
import sys
sys.path.append("..")
warnings.simplefilter("ignore")
from Scripts.Data_cleaning import load_data,clean_data
from Scripts.data_visualization import Data_visualiz

# %% [markdown]
# ###### Load datasets

# %%
sample_data = load_data('../data/sample_submission.csv')
store_data = load_data('../data/store.csv')
train_data = load_data('../data/train.csv')
test_data = load_data('../data/test.csv')

# %%
store = clean_data(store_data)
train = clean_data(train_data)
test = clean_data(test_data)

# %%
sample_data.head()
# Out:
#    Id  Sales
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0

# %%
store_data.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
train_data.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
test_data.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %% [markdown]
# ### Perform Descriptive analytics

# %%
def descriptive(df):
    df = clean_data(df)
    info_ = df.descriptive_statistics(info=True)
    print(info_)
    print('*'*50)
    shape_ = df.descriptive_statistics(shape=True)
    print(shape_)
    print('*'*50)
    stats = df.descriptive_statistics(describe=True),
    print(stats)
    print('*'*50)
    Missing_values = df.descriptive_statistics(missing_values=True)
    print(Missing_values)
    print('*'*50)

# %% [markdown]
# ###### store data

# %%
descriptive(store_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB
# None
# **************************************************
# (1115, 10)
# **************************************************
# ...

# %% [markdown]
# ###### train_data

# %%
descriptive(train_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB
# None
# **************************************************
# (1017209, 9)
# **************************************************
# (              Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# ...

# %% [markdown]
# ###### test data

# %%
descriptive(test_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41088 entries, 0 to 41087
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             41088 non-null  int64
#  1   Store          41088 non-null  int64
#  2   DayOfWeek      41088 non-null  int64
#  3   Date           41088 non-null  object
#  4   Open           41077 non-null  float64
#  5   Promo          41088 non-null  int64
#  6   StateHoliday   41088 non-null  object
#  7   SchoolHoliday  41088 non-null  int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 2.5+ MB
# None
# **************************************************
# (41088, 8)
# **************************************************
# (                 Id         Store     DayOfWeek          Open         Promo  \
# count  41088.000000  41088.000000  41088.000000  41077.000000  41088.000000
# mean   20544.500000    555.899533      3.979167      0.854322      0.395833
# ...

# %% [markdown]
# ##### remove outliers

# %%
store.fix_outliers(store_data,['CompetitionDistance','CompetitionOpenSinceYear'])
# Out:
#       CompetitionDistance  CompetitionOpenSinceYear
# 0                  1270.0                    2008.0
# 1                   570.0                    2007.0
# 2                 14130.0                    2006.0
# 3                   620.0                    2009.0
# 4                  2325.0                    2010.0
# ...                   ...                       ...
# 1110               1900.0                    2014.0
# 1111               1880.0                    2006.0
# 1112               9260.0                       NaN
# 1113                870.0                       NaN
# 1114               5350.0                       NaN
#
# [1115 rows x 2 columns]

# %%
train.fix_outliers(train_data,['Sales','Customers'])
# Out:
#           Sales  Customers
# 0        5263.0      555.0
# 1        6064.0      625.0
# 2        8314.0      821.0
# 3        5744.0      609.0
# 4        4822.0      559.0
# ...         ...        ...
# 1017204     0.0        0.0
# 1017205     0.0        0.0
# 1017206     0.0        0.0
# 1017207     0.0        0.0
# 1017208     0.0        0.0
#
# [1017209 rows x 2 columns]

# %% [markdown]
# ##### handling missing values

# %%
store_data[store_data['Promo2']==0]
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 3         4         c          c                620.0
# 4         5         a          a               2325.0
# 5         6         a          a                310.0
# 6         7         a          c               2325.0
# ...     ...       ...        ...                  ...
# 1107   1108         a          a                540.0
# 1109   1110         c          c                900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 3                           9.0                    2009.0       0
# 4                           4.0                    2010.0       0
# ...

# %% [markdown]
# based on the table above where we have promo2 is equal to 0 means that store is not participating, the last three columns should be null. So that handle missing values we can replace by them by 0 means that they are not available

# %%
store.filling_nan(store_data,['Promo2SinceWeek','Promo2SinceYear',],0)

# %%
#handling interval column
store.filling_nan(store_data,['PromoInterval'],"0,0,0,0") #we have to replace with four zeros since we have four variables

# %%
#recheck for nan values in store_data
store_data.isna().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek                0
# Promo2SinceYear                0
# PromoInterval                  0
# dtype: int64

# %% [markdown]
# for the CompetitionOpenSinceMonth and CompetitionOpenSinceYear columns is not the same since we have some rows with 1 in the promo2. let us check

# %%
store_data[store_data['CompetitionOpenSinceYear'].isna()].head()
# Out:
#     Store StoreType Assortment  CompetitionDistance  \
# 11     12         a          c               1070.0
# 12     13         d          a                310.0
# 15     16         a          c               3270.0
# 18     19         a          c               3240.0
# 21     22         a          a               1040.0
#
#     CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 11                        NaN                       NaN       1
# 12                        NaN                       NaN       1
# 15                        NaN                       NaN       0
# 18                        NaN                       NaN       1
# 21                        NaN                       NaN       1
#
#     Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 11             13.0           2010.0   Jan,Apr,Jul,Oct
# 12             45.0           2009.0   Feb,May,Aug,Nov
# 15              0.0              0.0           0,0,0,0
# ...

# %% [markdown]
# we can see that for the first two rows, the store is starting but we have null values in `CompetitionOpenSinceMonth` and `CompetitionOpenSinceYear`. Therefore, we can impute the missing values by filling with minimun values since that nan values might be due to the fact there were already the competition since the store open

# %%
store.filling_nan(store_data,['CompetitionOpenSinceMonth'],store_data.CompetitionOpenSinceMonth.min())
store.filling_nan(store_data,['CompetitionOpenSinceYear'],store_data.CompetitionOpenSinceYear.min())

# %%
store_data.isna().sum()
# Out:
# Store                        0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          3
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %% [markdown]
# for the CompetitionDistance column, 3 rows don't count much on the whole dataset, so we might drop them. Which is the same to the test data, the percentage of missing value is very small

# %%
store.drop_rows(store_data)

# %%
store_data.isna().sum()
# Out:
# Store                        0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %%
test.drop_rows(test_data)

# %%
test_data.isna().sum()
# Out:
# Id               0
# Store            0
# DayOfWeek        0
# Date             0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %% [markdown]
# ##### handling columns type

# %%
# converting some columns to int 
store.convert_to_int(store_data,['CompetitionOpenSinceMonth','CompetitionOpenSinceYear','Promo2SinceWeek','Promo2SinceYear'])

# %%
store_data.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                          9
# 1      2         a          a                570.0                         11
# 2      3         a          a              14130.0                         12
# 3      4         c          c                620.0                          9
# 4      5         a          a               2325.0                          4
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                      2008       0                0                0
# 1                      2007       1               13             2010
# 2                      2006       1               14             2011
# 3                      2009       0                0                0
# 4                      2010       0                0                0
#
#      PromoInterval
# 0          0,0,0,0
# 1  Jan,Apr,Jul,Oct
# ...

# %%
#convert date column to datetime in train and test data
train.convert_to_datetime(train_data,['Date'])
test.convert_to_datetime(test_data,['Date'])

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  datetime64[ns]
#  3   Sales          1017209 non-null  float64
#  4   Customers      1017209 non-null  float64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(1)
# memory usage: 69.8+ MB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41077 entries, 0 to 41087
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             41077 non-null  int64
#  1   Store          41077 non-null  int64
#  2   DayOfWeek      41077 non-null  int64
#  3   Date           41077 non-null  datetime64[ns]
#  4   Open           41077 non-null  float64
#  5   Promo          41077 non-null  int64
#  6   StateHoliday   41077 non-null  object
#  7   SchoolHoliday  41077 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(1)
# memory usage: 2.8+ MB

# %% [markdown]
# ###### checking for duplicates

# %%
store_data.duplicated().sum()
# Out:
# 0

# %%
train_data.duplicated().sum()
# Out:
# 0

# %%
test_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# no duplicates were found

# %% [markdown]
# ###### transform date column

# %%
train.transform_columns(train_data,'Date')
test.transform_columns(test_data,'Date')

# %% [markdown]
# ###### merge dataset

# %%
df1 = pd.merge(store_data,train_data,how='left',on='Store')
df2 = pd.merge(store_data,test_data,how='left',on='Store')

# %%
df1.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                          9
# 1      1         c          a               1270.0                          9
# 2      1         c          a               1270.0                          9
# 3      1         c          a               1270.0                          9
# 4      1         c          a               1270.0                          9
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                      2008       0                0                0
# 1                      2008       0                0                0
# 2                      2008       0                0                0
# 3                      2008       0                0                0
# 4                      2008       0                0                0
#
#   PromoInterval  ...  Customers Open  Promo  StateHoliday  SchoolHoliday  \
# ...

# %%
df2.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                          9
# 1      1         c          a               1270.0                          9
# 2      1         c          a               1270.0                          9
# 3      1         c          a               1270.0                          9
# 4      1         c          a               1270.0                          9
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                      2008       0                0                0
# 1                      2008       0                0                0
# 2                      2008       0                0                0
# 3                      2008       0                0                0
# 4                      2008       0                0                0
#
#   PromoInterval  ...       Date  Open Promo  StateHoliday  SchoolHoliday  \
# ...

# %%
df1.shape
# Out:
# (1014567, 23)

# %%
df2.shape
# Out:
# (41250, 22)

# %%
df1.isna().sum()
# Out:
# Store                        0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# DayOfWeek                    0
# Date                         0
# Sales                        0
# Customers                    0
# Open                         0
# Promo                        0
# StateHoliday                 0
# SchoolHoliday                0
# Days                         0
# months                       0
# Years                        0
# DayOfYear                    0
# WeekOfYear                   0
# dtype: int64

# %%
df2.isna().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            0
# CompetitionOpenSinceMonth      0
# CompetitionOpenSinceYear       0
# Promo2                         0
# Promo2SinceWeek                0
# Promo2SinceYear                0
# PromoInterval                  0
# Id                           258
# DayOfWeek                    258
# Date                         258
# Open                         258
# Promo                        258
# StateHoliday                 258
# SchoolHoliday                258
# Days                         258
# months                       258
# Years                        258
# DayOfYear                    258
# WeekOfYear                   258
# dtype: int64

# %%
df2[df2['Date'].isna()].head()
# Out:
#      Store StoreType Assortment  CompetitionDistance  \
# 48       2         a          a                570.0
# 97       4         c          c                620.0
# 98       5         a          a               2325.0
# 99       6         a          a                310.0
# 580     17         a          a                 50.0
#
#      CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 48                          11                      2007       1
# 97                           9                      2009       0
# 98                           4                      2010       0
# 99                          12                      2013       0
# 580                         12                      2005       1
#
#      Promo2SinceWeek  Promo2SinceYear    PromoInterval  ...  Date  Open Promo  \
# 48                13             2010  Jan,Apr,Jul,Oct  ...   NaT   NaN   NaN
# 97                 0                0          0,0,0,0  ...   NaT   NaN   NaN
# ...

# %% [markdown]
# nan values correspond with observations whereby the didn't record date, so I dropped them

# %%
df2.dropna(inplace=True)

# %%
df2.isna().sum()
# Out:
# Store                        0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# Id                           0
# DayOfWeek                    0
# Date                         0
# Open                         0
# Promo                        0
# StateHoliday                 0
# SchoolHoliday                0
# Days                         0
# months                       0
# Years                        0
# DayOfYear                    0
# WeekOfYear                   0
# dtype: int64

# %% [markdown]
# ###### checking for duplicates

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df1.to_csv('../data/train-data.csv',index=False)
df2.to_csv('../data/test-data.csv',index=False)
